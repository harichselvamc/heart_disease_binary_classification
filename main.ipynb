# %% [markdown]
# # Dataset Overview

# %% [markdown]
# 1. age in years
# 2. sex ( 1 male : 0 female )
# 3. chest pain type
# 4. resting blood pressure
# 5. serum cholestoral
# 6. fasting blood sugar
# 7. resting ecg
# 8. maximum heart rate acheived
# 9. exercise induced angina
# 10. ST depression induced by exercise relative to rest
# 11. slope of the peak exerice to ST segment
# 12. number of major vessels(0-3)colored by flourosopy
# 13. thal ( 3: normal , 6 : fixed defect , 7 : reversable defect )
# 14. target ( 1 disease , 0 no disease)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#fetch and read the csv file 
# data_path='dataset/heart.csv'
data_path='dataset/heart_train_val.csv'
heartdf=pd.read_csv(data_path)
heartdf
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 256   57    0   0       140   241    0        1      123      1      0.2
# 257   45    1   3       110   264    0        1      132      0      1.2
# 258   68    1   0       144   193    1        1      141      0      3.4
# 259   57    1   0       130   131    0        1      115      1      1.2
# 260   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#shape and size of the data frame 
heartdf.shape
# Out:
# (261, 14)

# %%
heartdf.count()
# Out:
# age         261
# sex         261
# cp          261
# trestbps    261
# chol        261
# fbs         261
# restecg     261
# thalach     261
# exang       261
# oldpeak     261
# slope       261
# ca          261
# thal        261
# target      261
# dtype: int64

# %%
heartdf.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  261.000000  261.000000  261.000000  261.000000  261.000000  261.000000
# mean    54.352490    0.666667    0.977011  131.578544  247.704981    0.160920
# std      9.028922    0.472310    1.041194   18.029211   52.257067    0.368163
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  261.000000  261.000000  261.000000  261.000000  261.000000  261.000000
# mean     0.536398  149.662835    0.333333    1.027586    1.413793    0.701149
# ...

# %%
heartdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       261 non-null    int64
#  1   sex       261 non-null    int64
#  2   cp        261 non-null    int64
#  3   trestbps  261 non-null    int64
#  4   chol      261 non-null    int64
#  5   fbs       261 non-null    int64
#  6   restecg   261 non-null    int64
#  7   thalach   261 non-null    int64
#  8   exang     261 non-null    int64
#  9   oldpeak   261 non-null    float64
#  10  slope     261 non-null    int64
#  11  ca        261 non-null    int64
#  12  thal      261 non-null    int64
#  13  target    261 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 28.7 KB

# %%
#check for any null values
heartdf.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#boxplot for all columns 
for i in heartdf.columns:
    sns.boxplot(x=heartdf[i])
    plt.show()

# %%
#create a copy for visualization

heartdf_copy= heartdf.copy()

# %%
heartdf_copy
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 256   57    0   0       140   241    0        1      123      1      0.2
# 257   45    1   3       110   264    0        1      132      0      1.2
# 258   68    1   0       144   193    1        1      141      0      3.4
# 259   57    1   0       130   131    0        1      115      1      1.2
# 260   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#comparing the number healthy vs number of heart patients
heartdf_copy.target=heartdf_copy.target.map({0:"healthy",1:"Heart patient"})
heartdf_copy
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 256   57    0   0       140   241    0        1      123      1      0.2
# 257   45    1   3       110   264    0        1      132      0      1.2
# 258   68    1   0       144   193    1        1      141      0      3.4
# 259   57    1   0       130   131    0        1      115      1      1.2
# 260   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal         target
# 0        0   0     1  Heart patient
# ...

# %%
sns.countplot(x='target',data=heartdf_copy)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
# comparing number of male and female 

heartdf_copy.sex=heartdf_copy.sex.map({0:'female',1:'male'})
sns.countplot(x='sex',data=heartdf_copy,hue=heartdf_copy.target)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
heartdf_copy
# Out:
#      age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    male   3       145   233    1        0      150      0      2.3
# 1     37    male   2       130   250    0        1      187      0      3.5
# 2     41  female   1       130   204    0        0      172      0      1.4
# 3     56    male   1       120   236    0        1      178      0      0.8
# 4     57  female   0       120   354    0        1      163      1      0.6
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 256   57  female   0       140   241    0        1      123      1      0.2
# 257   45    male   3       110   264    0        1      132      0      1.2
# 258   68    male   0       144   193    1        1      141      0      3.4
# 259   57    male   0       130   131    0        1      115      1      1.2
# 260   57  female   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal         target
# ...

# %%
#comparing age with health 
plt.hist(heartdf_copy[heartdf_copy.target=='Heart patient']['age'],color='b',alpha=0.5,bins=15,label='patient')
plt.hist(heartdf_copy[heartdf_copy.target=='healthy']['age'],color='g',alpha=0.5,bins=15,label='healthy')
plt.legend()
plt.show()

# %%
#comparing cholestrol with health 
plt.hist(heartdf_copy[heartdf_copy.target=='Heart patient']['chol'],color='b',alpha=0.5,bins=15,label='patient')
plt.hist(heartdf_copy[heartdf_copy.target=='healthy']['chol'],color='g',alpha=0.5,bins=15,label='healthy')
plt.legend()
plt.show()

# %%
heartdf
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 256   57    0   0       140   241    0        1      123      1      0.2
# 257   45    1   3       110   264    0        1      132      0      1.2
# 258   68    1   0       144   193    1        1      141      0      3.4
# 259   57    1   0       130   131    0        1      115      1      1.2
# 260   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#divide the dataset for model 
x=heartdf.drop('target',axis=1)
y=heartdf['target']

# %%
x.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int64

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers

# %%
#defining the sequential model for binary classification
model=keras.Sequential()
model.add(layers.Dense(11,activation='relu',input_dim=13))
model.add(layers.Dense(1,activation='sigmoid'))

# %%
#compile and fit the model 

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(x,y,validation_split=0.22,epochs=300)
# Out:
# Epoch 1/300
# 7/7 [==============================] - 1s 32ms/step - loss: 34.9144 - accuracy: 0.7241 - val_loss: 108.0273 - val_accuracy: 0.0000e+00
# Epoch 2/300
# 7/7 [==============================] - 0s 8ms/step - loss: 29.7671 - accuracy: 0.7241 - val_loss: 89.4112 - val_accuracy: 0.0000e+00
# Epoch 3/300
# 7/7 [==============================] - 0s 7ms/step - loss: 24.4777 - accuracy: 0.7241 - val_loss: 71.5398 - val_accuracy: 0.0000e+00
# Epoch 4/300
# 7/7 [==============================] - 0s 7ms/step - loss: 19.3103 - accuracy: 0.7241 - val_loss: 53.8318 - val_accuracy: 0.0000e+00
# Epoch 5/300
# 7/7 [==============================] - 0s 9ms/step - loss: 14.4778 - accuracy: 0.7192 - val_loss: 36.2213 - val_accuracy: 0.0000e+00
# Epoch 6/300
# 7/7 [==============================] - 0s 11ms/step - loss: 10.0105 - accuracy: 0.6798 - val_loss: 21.6289 - val_accuracy: 0.2069
# Epoch 7/300
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel("loss")
plt.xlabel("no of epochs")
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel("accuracy")
plt.xlabel("no of epochs")
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
import numpy 
from numpy import array 

#input for 13 features
xnew=numpy.array([[67,1,0,125,254,1,1,163,0,0.2,1,2,3]])
xnew=numpy.array(xnew,dtype=numpy.float64)

# %%
#making predictions
ynew=(model.predict(xnew))
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000015075B55DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 50ms/step

# %%
ynew
# Out:
# array([[0.38869828]], dtype=float32)

# %%
ynew=(model.predict(xnew)>0.5).astype("int32")
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
ynew
# Out:
# array([[0]])

# %%
#fetch and read the csv file 
# data_path='dataset/heart.csv'
data_path_testing='dataset/heart_test.csv'
heartdf_testing=pd.read_csv(data_path)
heartdf_testing
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 256   57    0   0       140   241    0        1      123      1      0.2
# 257   45    1   3       110   264    0        1      132      0      1.2
# 258   68    1   0       144   193    1        1      141      0      3.4
# 259   57    1   0       130   131    0        1      115      1      1.2
# 260   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#divide the dataset for model 
xtest=heartdf_testing.drop('target',axis=1)
ytest=heartdf_testing['target']

# %%
#performing evaluation action with independent data
evaluation_history=model.evaluate(xtest,ytest)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8429

# %%
evaluation_history
# Out:
# [0.37134772539138794, 0.8429118990898132]
